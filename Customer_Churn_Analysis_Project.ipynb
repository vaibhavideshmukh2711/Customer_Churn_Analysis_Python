# %% [markdown]
# # Customer Churn Analysis Project PYTHON-EDA

# %% [markdown]
# ## STEP 0: Understand Business Problem
#
# Goal: Identify why customers are leaving (churn)
# Customer churn leads to revenue loss. The objective is to analyze customer data
# to identify key factors influencing churn and provide actionable insights
# to improve customer retention.

# %% [markdown]
# ## STEP 1: Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## STEP 2: Load Dataset

# %%
df = pd.read_csv(r"C:\vaibhavi_upgrade\PYTHON_MATERIAL\telecom_customer_Dataset.csv")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ## STEP 3: Understand Data Stucture
# This step gives a high-level overview of the dataset.

# %%
df.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0  Electronic check          29.85         29.85     No
# 1      Mailed check          56.95       1889.50     No
#
# [2 rows x 21 columns]

# %%
df.tail(2)
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 7041  8361-LTMKD   Male              1     Yes         No       4
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 7041          Yes           Yes     Fiber optic             No  ...
# 7042          Yes            No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#       Churn
# 7041    Yes
# 7042     No
#
# [2 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.371149       64.761692   2283.300441
# std         0.368612    24.559481       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# ## STEP 4 : Data Cleaning

# %% [markdown]
# Check Missing Values

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# Handle Missing Values

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# Remove Duplicates

# %%
df = df.drop_duplicates()

# %%
df['TotalCharges']=df['TotalCharges'].replace(" ","0")
df["TotalCharges"]=df['TotalCharges'].astype(float)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_31924\3938467916.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TotalCharges']=df['TotalCharges'].replace(" ","0")
# C:\Users\Hp\AppData\Local\Temp\ipykernel_31924\3938467916.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["TotalCharges"]=df['TotalCharges'].astype(float)

# %%
df.describe()          #only for integer Values
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.describe(include=object)
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7032   7032    7032       7032         7032          7032
# unique        7032      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3549    3639       4933         6352          3385
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7032           7032         7032             7032
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3497         3087             3094
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7032        7032            7032            7032
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
def conv(value):               #Convert 0 and 1 into yes and no
    if value == 1:
         return "yes"
    else:
        return "no"
    
df['SeniorCitizen']= df['SeniorCitizen'].apply(conv)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_31924\426098307.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SeniorCitizen']= df['SeniorCitizen'].apply(conv)

# %%
df.head(2)
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            no     Yes         No       1           No
# 1  5575-GNVDE    Male            no      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0  Electronic check          29.85         29.85     No
# 1      Mailed check          56.95       1889.50     No
#
# [2 rows x 21 columns]

# %% [markdown]
# # STEP 5: Target Variable Analysis (Churn)

# %% [markdown]
# Total Customer Churn

# %%
ax=sns.countplot(x='Churn',data=df)
ax.bar_label(ax.containers[0])
plt.show()

# %%
gb = df.groupby("Churn").agg({'Churn':'count'})
gb
# Out:
#        Churn
# Churn
# No      5163
# Yes     1869

# %%
plt.figure(figsize=(4,4))
gb = df.groupby("Churn").agg({"Churn":"count"})
plt.pie(gb['Churn'],labels= gb.index, autopct="%1.2f%%")
plt.title("Customer Churn ")
plt.show()

# %% [markdown]
# 26.58% Customers have churn out

# %%
df.head(2)
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            no     Yes         No       1           No
# 1  5575-GNVDE    Male            no      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0  Electronic check          29.85         29.85     No
# 1      Mailed check          56.95       1889.50     No
#
# [2 rows x 21 columns]

# %% [markdown]
# Customer churn by Gender

# %%
ax=sns.countplot(x='gender',data=df, hue='Churn')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Customer Churn by gender")
plt.show()

# %% [markdown]
# Female customer more churn out according to male customer

# %%
ax=sns.countplot(x='SeniorCitizen',data=df, hue='Churn')   #Hue = Used to split data by category using colors
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Churn by SeniorCitizen")
plt.show()

# %%
ax=sns.countplot(x='SeniorCitizen',data=df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Churn by SeniorCitizen")
plt.show()

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
ax=sns.countplot(x='Dependents',data=df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("SeniorCitizen")
plt.show()

# %%
ax=sns.countplot(x='Partner',data=df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("SeniorCitizen")
plt.show()

# %% [markdown]
# # STEP 6: Univariate Analysis

# %%
plt.figure(figsize=(9,4))
sns.histplot(x='tenure', data=df , bins=10)  #bins = Groups data into ranges
plt.show()

# %%
sns.histplot(df['tenure'], kde=True)    #kde (Kernel Density Estimate) KDE = smooth line
plt.title("Tenure Distribution")
plt.show()

# %%
plt.figure(figsize=(9,4))
sns.histplot(x="tenure", data=df, bins=72, hue="Churn")
plt.show()

# %% [markdown]
# Customer who have churn our services for a long time and sort time have stayed

# %%
df.head(2)
# Out:
#    customerID  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            no     Yes         No       1           No
# 1  5575-GNVDE    Male            no      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0  Electronic check          29.85         29.85     No
# 1      Mailed check          56.95       1889.50     No
#
# [2 rows x 21 columns]

# %%
ax=sns.countplot(x="Contract" , data=df , hue="Churn")
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("customer Count by contract")
plt.show()

# %%
sns.set_palette("Set2")

# %%
sns.reset_defaults()

# %% [markdown]
# from above these chart who have month to month contract are likely to churn from those who have 1 or 2 year contract

# %%
plt.figure(figsize=(9,4))
ax=sns.countplot(x="PaymentMethod", data=df, hue='Churn')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('customer count by contract')
plt.show()

# %% [markdown]
# Customers who use electronic checks have a higher likelihood of churning.

# %%
sns.histplot(df['MonthlyCharges'], kde=True  )
plt.title("Monthly Charges Distribution")
plt.show()

# %% [markdown]
# # STEP 7: Bivariate Analysis (MOST IMPORTANT)

# %%
sns.boxplot(x="Churn" , y='tenure', data=df)
plt.show()

# %% [markdown]
# Churn vs Monthly Charges

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.show()

# %% [markdown]
# Categorical Analysis

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='Contract', hue='Churn', data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # STEP 8: Correlation Analysis

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Additional

# %% [markdown]
# Churn Rate %

# %%
churn_rate = df['Churn'].value_counts(normalize=True) * 100
print(churn_rate)
# Out:
# Churn
# No     73.421502
# Yes    26.578498
# Name: proportion, dtype: float64

# %% [markdown]
# Group Analysis

# %%
df.groupby('Contract')['Churn'].value_counts(normalize=True)
# Out:
# Contract        Churn
# Month-to-month  No       0.572903
#                 Yes      0.427097
# One year        No       0.887228
#                 Yes      0.112772
# Two year        No       0.971513
#                 Yes      0.028487
# Name: proportion, dtype: float64

# %% [markdown]
# # STEP 9 : Multivariate Analysis (ADVANCED)

# %%
pivot = pd.crosstab(df['Contract'], df['Churn'], normalize='index')
pivot.plot(kind='bar', stacked=True)
plt.title("Churn Rate by Contract Type")
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %% [markdown]
# # STEP 10 : KEY INSIGHTS

# %% [markdown]
# ## 1. Customers with month-to-month contracts show highest churn rate.
# ## 2. Customers with low tenure are more likely to leave early.
# ## 3. Higher monthly charges are associated with increased churn.
# ## 4. Certain service types influence churn behavior.

# %% [markdown]
# # 11. BUSINESS RECOMMENDATIONS

# %% [markdown]
# ## 1. Offer discounts or loyalty programs to high-paying customers.
# ## 2. Encourage customers to switch to long-term contracts.
# ## 3. Focus on onboarding experience for new customers.
# ## 4. Improve service quality for high-churn segments.
